# %%
# !pip install torch transformers datasets accelerate
# Out:
# Collecting torch
#   Downloading torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting transformers
#   Downloading transformers-5.4.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: datasets in c:\users\jaisw\anaconda3\lib\site-packages (4.8.4)
# Collecting accelerate
#   Downloading accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in c:\users\jaisw\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\jaisw\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\jaisw\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jaisw\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\jaisw\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\jaisw\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\jaisw\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\users\jaisw\anaconda3\lib\site-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\jaisw\anaconda3\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jaisw\anaconda3\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\jaisw\anaconda3\lib\site-packages (from transformers) (6.0.3)
# Collecting regex>=2025.10.22 (from transformers)
#   Downloading regex-2026.3.32-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer in c:\users\jaisw\anaconda3\lib\site-packages (from transformers) (0.17.4)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\jaisw\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in c:\users\jaisw\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jaisw\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\users\jaisw\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\users\jaisw\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\jaisw\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\jaisw\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\jaisw\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\jaisw\anaconda3\lib\site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\jaisw\anaconda3\lib\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in c:\users\jaisw\anaconda3\lib\site-packages (from datasets) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in c:\users\jaisw\anaconda3\lib\site-packages (from datasets) (2.32.5)
# Requirement already satisfied: xxhash in c:\users\jaisw\anaconda3\lib\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in c:\users\jaisw\anaconda3\lib\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\jaisw\anaconda3\lib\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: psutil in c:\users\jaisw\anaconda3\lib\site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\jaisw\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\jaisw\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jaisw\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jaisw\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jaisw\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\jaisw\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\jaisw\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jaisw\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jaisw\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jaisw\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\jaisw\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jaisw\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jaisw\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jaisw\anaconda3\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jaisw\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jaisw\anaconda3\lib\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jaisw\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\jaisw\anaconda3\lib\site-packages (from typer->transformers) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\jaisw\anaconda3\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jaisw\anaconda3\lib\site-packages (from typer->transformers) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jaisw\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jaisw\anaconda3\lib\site-packages (from rich>=10.11.0->typer->transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jaisw\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->transformers) (0.1.2)
# Downloading torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
#    ---------------------------------------- 0.0/114.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/114.6 MB ? eta -:--:--
#    ---------------------------------------- 1.0/114.6 MB 4.6 MB/s eta 0:00:25
#    - -------------------------------------- 3.4/114.6 MB 7.8 MB/s eta 0:00:15
#    - -------------------------------------- 5.5/114.6 MB 9.1 MB/s eta 0:00:12
#    -- ------------------------------------- 7.6/114.6 MB 9.3 MB/s eta 0:00:12
#    --- ------------------------------------ 10.5/114.6 MB 10.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 12.3/114.6 MB 9.9 MB/s eta 0:00:11
#    ---- ----------------------------------- 13.1/114.6 MB 9.8 MB/s eta 0:00:11
#    ----- ---------------------------------- 16.8/114.6 MB 10.0 MB/s eta 0:00:10
#    ------ --------------------------------- 18.4/114.6 MB 10.1 MB/s eta 0:00:10
#    ------- -------------------------------- 21.8/114.6 MB 10.3 MB/s eta 0:00:10
#    -------- ------------------------------- 24.6/114.6 MB 10.5 MB/s eta 0:00:09
#    --------- ------------------------------ 26.7/114.6 MB 10.5 MB/s eta 0:00:09
#    ---------- ----------------------------- 29.6/114.6 MB 10.7 MB/s eta 0:00:08
#    ----------- ---------------------------- 32.2/114.6 MB 10.8 MB/s eta 0:00:08
#    ------------ --------------------------- 35.7/114.6 MB 11.1 MB/s eta 0:00:08
#    ------------- -------------------------- 39.3/114.6 MB 11.5 MB/s eta 0:00:07
#    --------------- ------------------------ 43.3/114.6 MB 12.0 MB/s eta 0:00:06
#    ---------------- ----------------------- 46.4/114.6 MB 12.1 MB/s eta 0:00:06
#    ----------------- ---------------------- 49.8/114.6 MB 12.3 MB/s eta 0:00:06
#    ------------------ --------------------- 54.0/114.6 MB 12.7 MB/s eta 0:00:05
#    -------------------- ------------------- 57.7/114.6 MB 13.0 MB/s eta 0:00:05
#    --------------------- ------------------ 61.1/114.6 MB 13.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 64.2/114.6 MB 13.2 MB/s eta 0:00:04
#    ----------------------- ---------------- 67.1/114.6 MB 13.2 MB/s eta 0:00:04
#    ------------------------ --------------- 70.3/114.6 MB 13.3 MB/s eta 0:00:04
#    ------------------------- -------------- 73.4/114.6 MB 13.3 MB/s eta 0:00:04
#    -------------------------- ------------- 75.8/114.6 MB 13.2 MB/s eta 0:00:03
#    --------------------------- ------------ 77.9/114.6 MB 13.1 MB/s eta 0:00:03
#    --------------------------- ------------ 79.7/114.6 MB 13.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 81.8/114.6 MB 12.8 MB/s eta 0:00:03
#    ----------------------------- ---------- 85.5/114.6 MB 12.9 MB/s eta 0:00:03
#    ------------------------------- -------- 89.4/114.6 MB 13.1 MB/s eta 0:00:02
#    -------------------------------- ------- 91.8/114.6 MB 13.0 MB/s eta 0:00:02
#    --------------------------------- ------ 95.7/114.6 MB 13.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 99.6/114.6 MB 13.4 MB/s eta 0:00:02
#    ----------------------------------- --- 103.5/114.6 MB 13.5 MB/s eta 0:00:01
#    ------------------------------------ -- 107.2/114.6 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------- - 109.8/114.6 MB 13.7 MB/s eta 0:00:01
#    ------------------------------------- - 111.4/114.6 MB 13.4 MB/s eta 0:00:01
#    --------------------------------------  114.0/114.6 MB 13.4 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.4 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.4 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.4 MB/s eta 0:00:01
#    --------------------------------------  114.3/114.6 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 114.6/114.6 MB 12.0 MB/s  0:00:09
# Downloading transformers-5.4.0-py3-none-any.whl (10.1 MB)
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------- ----------------------------- 2.6/10.1 MB 21.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.8/10.1 MB 17.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.9/10.1 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 15.0 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------------------------------ --------- 2.1/2.7 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 9.2 MB/s  0:00:00
# Downloading accelerate-1.13.0-py3-none-any.whl (383 kB)
# Downloading regex-2026.3.32-cp313-cp313-win_amd64.whl (277 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Installing collected packages: safetensors, regex, torch, tokenizers, accelerate, transformers
#
#   Attempting uninstall: regex
#
#     Found existing installation: regex 2025.9.1
#
#     Uninstalling regex-2025.9.1:
#
#       Successfully uninstalled regex-2025.9.1
#
#    ------ --------------------------------- 1/6 [regex]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    ------------- -------------------------- 2/6 [torch]
#    -------------------------- ------------- 4/6 [accelerate]
#    -------------------------- ------------- 4/6 [accelerate]
#    -------------------------- ------------- 4/6 [accelerate]
#    -------------------------- ------------- 4/6 [accelerate]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    --------------------------------- ------ 5/6 [transformers]
#    ---------------------------------------- 6/6 [transformers]
#
# Successfully installed accelerate-1.13.0 regex-2026.3.32 safetensors-0.7.0 tokenizers-0.22.2 torch-2.11.0 transformers-5.4.0

# %%
# Check PyTorch
try:
    import torch
    print("PyTorch:", torch.__version__)
    print("GPU available:", torch.cuda.is_available())
    if torch.cuda.is_available():
        print("GPU:", torch.cuda.get_device_name(0))
    else:
        print("Device: CPU only")
except ImportError:
    print("PyTorch not installed")

# Check Transformers
try:
    import transformers
    print("Transformers:", transformers.__version__)
except ImportError:
    print("Transformers not installed")
# Out:
# PyTorch: 2.11.0+cpu
# GPU available: False
# Device: CPU only
# Transformers: 5.4.0
